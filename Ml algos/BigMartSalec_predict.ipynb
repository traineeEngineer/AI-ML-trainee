# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
big_mart=pd.read_csv('../MachineLearning/datasets/bigmart.csv')

# %%
big_mart.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
big_mart.shape
# Out:
# (8523, 12)

# %%
big_mart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
big_mart.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
big_mart['Item_Weight']=big_mart['Item_Weight'].fillna(big_mart['Item_Weight'].mean())
big_mart['Outlet_Size']=big_mart['Outlet_Size'].fillna(big_mart['Outlet_Size'][0])

# %%
big_mart.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
big_mart.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
plt.figure(figsize=(13,8))
sns.heatmap(big_mart.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,6))
sns.distplot(big_mart['Item_Weight'])
# Out:
# <Axes: xlabel='Item_Weight', ylabel='Density'>

# %%
plt.figure(figsize=(12,6))
sns.distplot(big_mart['Item_Visibility'])
# Out:
# <Axes: xlabel='Item_Visibility', ylabel='Density'>

# %%
plt.figure(figsize=(12,6))
sns.distplot(big_mart['Item_MRP'])
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Density'>

# %%
plt.figure(figsize=(12,6))
sns.distplot(big_mart['Item_Outlet_Sales'])
# Out:
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
big_mart['Item_Outlet_Sales']=np.log(1+big_mart['Item_Outlet_Sales'])

# %%
plt.figure(figsize=(12,6))
sns.distplot(big_mart['Item_Outlet_Sales'])
# Out:
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(big_mart['Outlet_Establishment_Year'])
# Out:
# <Axes: xlabel='Outlet_Establishment_Year', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(big_mart['Item_Fat_Content'])
# Out:
# <Axes: xlabel='Item_Fat_Content', ylabel='count'>

# %%
plt.figure(figsize=(20,8))
sns.countplot(big_mart['Item_Type'])
# Out:
# <Axes: xlabel='Item_Type', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(big_mart['Outlet_Size'])
# Out:
# <Axes: xlabel='Outlet_Size', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Item_Type',y='Item_Outlet_Sales',data=big_mart)
# Out:
# <Axes: xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Outlet_Type',y='Item_Outlet_Sales',data=big_mart)
# Out:
# <Axes: xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Outlet_Size',y='Item_Outlet_Sales',data=big_mart)
# Out:
# <Axes: xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(12,7))
sns.barplot('Outlet_Location_Type','Item_Outlet_Sales',hue='Outlet_Type',data=big_mart)
# Out:
# <Axes: xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %%
big_mart['Item_Fat_Content'].replace({'low fat':'Low Fat','LF':'Low Fat','reg':'Regular'},inplace=True)
big_mart['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(big_mart['Item_Fat_Content'])
# Out:
# <Axes: xlabel='Item_Fat_Content', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder
lbl_encode=LabelEncoder()
cols_to_encode=['Item_Identifier','Item_Type','Outlet_Identifier','Item_Fat_Content','Outlet_Size','Outlet_Location_Type','Outlet_Type']

for col in cols_to_encode:
    big_mart[col]=lbl_encode.fit_transform(big_mart[col])

# %%
big_mart
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 0         0.016047
# 1                   8        5.920                 1         0.019278
# 2                 662       17.500                 0         0.016760
# 3                1121       19.200                 1         0.000000
# 4                1297        8.930                 0         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 0         0.056783
# 8519              897        8.380                 1         0.046982
# 8520             1357       10.600                 0         0.035186
# 8521              681        7.210                 1         0.145221
# 8522               50       14.800                 0         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
X=big_mart.drop('Item_Outlet_Sales',axis=1)
Y=big_mart['Item_Outlet_Sales']

# %%
X
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 0         0.016047
# 1                   8        5.920                 1         0.019278
# 2                 662       17.500                 0         0.016760
# 3                1121       19.200                 1         0.000000
# 4                1297        8.930                 0         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 0         0.056783
# 8519              897        8.380                 1         0.046982
# 8520             1357       10.600                 0         0.035186
# 8521              681        7.210                 1         0.145221
# 8522               50       14.800                 0         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
Y
# Out:
# 0       8.225808
# 1       6.096776
# 2       7.648868
# 3       6.597664
# 4       6.903451
#           ...
# 8518    7.929984
# 8519    6.310436
# 8520    7.085159
# 8521    7.521100
# 8522    6.642056
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error,r2_score

# %%
big_mart
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 0         0.016047
# 1                   8        5.920                 1         0.019278
# 2                 662       17.500                 0         0.016760
# 3                1121       19.200                 1         0.000000
# 4                1297        8.930                 0         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 0         0.056783
# 8519              897        8.380                 1         0.046982
# 8520             1357       10.600                 0         0.035186
# 8521              681        7.210                 1         0.145221
# 8522               50       14.800                 0         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
item_sales = big_mart.groupby('Item_MRP')['Item_Outlet_Sales'].sum()

most_sold_mrp = item_sales.idxmax()

# Print the item mrp sold mostly
print('Item type mrp mostly:', most_sold_mrp)
# Out:
# Item type mrp mostly: 172.0422

# %%
item_sales = big_mart.groupby('Item_Type')['Item_Outlet_Sales'].sum()
most_sold_item = item_sales.idxmax()

print('Item type sold mostly:', most_sold_item)
# Out:
# Item type sold mostly: 6

# %%
item_sales = big_mart.groupby('Outlet_Location_Type')['Item_Outlet_Sales'].sum()
most_sold_location = item_sales.idxmax()


print('Item type location mostly:', most_sold_location)
# Out:
# Item type location mostly: 2

# %%
item_sales = big_mart.groupby('Outlet_Type')['Item_Outlet_Sales'].sum()
most_sold_type = item_sales.idxmax()

print('outlet type  mostly sold:', most_sold_type)
# Out:
# outlet type  mostly sold: 1

# %%
item_sales = big_mart.groupby('Item_Identifier')['Item_Outlet_Sales'].sum()
most_sold_identifier = item_sales.idxmax()


print('Item Identifier mostly:', most_sold_identifier)
# Out:
# Item Identifier mostly: 413

# %%
item_sales = big_mart.groupby('Item_Fat_Content')['Item_Outlet_Sales'].sum()
most_sold_Fat_item = item_sales.idxmax()


print('Item type fat mostly:', most_sold_Fat_item)
# Out:
# Item type fat mostly: 0

# %%
item_sales = big_mart.groupby('Outlet_Identifier')['Item_Outlet_Sales'].sum()
most_sold_Identifier = item_sales.idxmax()


print('Item type Identifier mostly:', most_sold_Identifier)
# Out:
# Item type Identifier mostly: 5

# %%
item_sales = big_mart.groupby('Outlet_Establishment_Year')['Item_Outlet_Sales'].sum()
most_sold_year = item_sales.idxmax()

print('Item type year mostly:', most_sold_year)
# Out:
# Item type year mostly: 1985

# %%
models = [
    LinearRegression(),
    DecisionTreeRegressor(max_depth=5),
    RandomForestRegressor(n_estimators =300, max_depth = 5,min_samples_split=7,max_features=2),
    GradientBoostingRegressor(n_estimators=100,learning_rate=0.01,max_depth=8),
    Ridge(),
    Lasso(),
    XGBRegressor(max_depth=3,learning_rate=0.01,n_estimators=500, booster='gbtree'),
    AdaBoostRegressor(learning_rate=0.02)
]
for model in models:
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(Y_test, y_pred, squared=False))
    r2score=r2_score(Y_test, y_pred)
    model_name = type(model).__name__
    print(f'{model_name} RMSE: {rmse} R2_score :{r2score} \n')
# Out:
# LinearRegression RMSE: 0.805892600855731 R2_score :0.5999617498989128
#
# DecisionTreeRegressor RMSE: 0.7266373879522149 R2_score :0.7355985665485738
#
# RandomForestRegressor RMSE: 0.7742228387451469 R2_score :0.6592336057932686
#
# GradientBoostingRegressor RMSE: 0.7858186632779958 R2_score :0.6383552191965257
#
# Ridge RMSE: 0.8058950634690717 R2_score :0.5999568601950196
#
# Lasso RMSE: 1.0138922940632094 R2_score :-0.0022132366770937217
#
# XGBRegressor RMSE: 0.7216970181960398 R2_score :0.7427161718399682
#
# AdaBoostRegressor RMSE: 0.7475612774350475 R2_score :0.7038034230735561
