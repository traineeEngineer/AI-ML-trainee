# %%
import pandas as pd

df=pd.read_csv("StudentPerformanceFactors.csv")
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
# at particular location
import numpy as np
df.insert(7,'Age',np.random.randint(100),True)
df
# Out:
#       Hours_Studied  Age  Attendance Parental_Involvement Access_to_Resources  \
# 0                23   14          84                  Low                High
# 1                19   14          64                  Low              Medium
# 2                24   14          98               Medium              Medium
# 3                29   14          89                  Low              Medium
# 4                19   14          92               Medium              Medium
# ...             ...  ...         ...                  ...                 ...
# 6602             25   14          69                 High              Medium
# 6603             23   14          76                 High              Medium
# 6604             20   14          90               Medium                 Low
# 6605             10   14          86                 High                High
# 6606             15   14          67               Medium                 Low
#
# ...

# %%
# at last of df
df=df.assign(Age=np.random.randint(100))
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...
