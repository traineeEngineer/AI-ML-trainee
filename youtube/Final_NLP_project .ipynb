# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from nltk.corpus import words as english_words
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import fasttext
from sklearn.model_selection import train_test_split
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\svygralingam\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df=pd.read_csv('./kabitakitchen.csv',encoding='Latin-1')

df2=pd.read_csv('./Nishafin.csv')

# %%
df=df.drop('id',axis=1)
df2=df2.drop('id',axis=1)

# %%
new_df=pd.concat([df,df2],ignore_index=True)

# %%
new_df.to_csv('combined_dataset.csv', index=False)

# %%
custom_hindi_stops=[
    "aadi", "aaj", "aap", "aapn", "aata", "aati", "aaya", "aay", "ab", "abb",
    "abbey", "abe", "abhi", "accha", "acha", "achcha", "agar", "aint", "aisa", "ais",
    "aisi", "alag", "andar", "ap", "apan", "apna", "apnaa", "apn", "apni", "aur", "avum",
    "aya", "aye","b", "baad", "baar", "bad", "bahut", "bana", "banai", "banao", "banaya",
    "banay", "banayi", "banda", "band", "bandi", "bane", "bani", "ba", "bata", "batao",
    "bhai", "bheetar", "bhi", "bhitar", "bht", "bilkul", "bohot", "bol", "bola", "bole",
    "boli", "bolo", "bolta", "bolt", "bolti", "bro", "btw", "caus", "chahiy", "chaiy",
    "chal", "chalega", "chhaiy", "clearli", "com", "de", "dede", "dega", "degi", "dekh",
    "dekha", "dekh", "dekhi", "dekho", "deng", "dhang", "di", "dijiy", "diya", "diyaa",
    "diy", "diyo", "doosra", "doosr", "dunga", "dungi", "dusra", "dusr", "dusri", "dvaara",
    "dvara", "dwaara", "dwara", "edu", "eg", "ek", "etc", "fr", "gaya", "gay", "gayi",
    "ghar", "h" ,"haan","hi" "hai", "hain", "hamara", "hamar", "hamari", "hamn", "han", "har",
    "hardli","hoga", "hoge", "hogi", "hona", "honaa", "hone", "hong", "hongi", "honi",
    "hota", "hotaa", "hote", "hoti", "hoyeng", "hoyengi", "hu", "hua", "hue", "huh",
    "hui", "hum", "humein", "humn", "hun", "huy", "huyi", "i'm","ie", "imo", "inasmuch", "inc",
    "inh", "inhi", "inho", "inka", "inkaa", "ink", "inki", "inn", "inner", "ins",
    "insofar", "ise", "isi", "iska", "iskaa", "isk", "iski", "ism", "isnt", "iss", "iss",
    "issi", "isski", "itna", "itn", "itni", "itno", "ityaadi", "ityadi","j", "ja", "jaa",
    "jab", "jabh", "jaha", "jahaan", "jahan", "jaisa", "jais", "jaisi", "jata", "jayega",
    "jidhar", "jin", "jinh", "jinhi", "jinho", "jinhon", "jinka", "jink", "jinki", "jinn",
    "ji", "jise", "jiska", "jisk", "jiski", "jism", "jiss", "jiss", "jitna", "jitn",
    "jitni", "jo", "jyaada", "jyada","k","ka", "kaafi", "kab", "kabhi", "kafi", "kaha",
    "kahaa", "kahaan", "kahan", "kahi", "kahin", "kaht", "kaisa", "kais", "kaisi", "kal",
    "kam", "kar", "kara", "kare", "karega", "karegi", "karen", "kareng", "kari", "kark",
    "karna", "karn", "karni", "karo", "karta", "kart", "karti", "karu", "karun", "karunga",
    "karungi", "kaun", "kaunsa", "kayi", "kch", "ke", "keh", "keht", "kept", "khud",
    "ki", "kin", "kine", "kinh", "kinho", "kinka", "kink", "kinki", "kinko", "kinn",
    "kino", "ki", "kise", "kisi", "kiska", "kisk", "kiski", "kisko", "kisliy", "kisn",
    "kitna", "kitn", "kitni", "kitno", "kiya", "kiy", "ko", "koi", "kon", "konsa",
    "koyi", "krna", "krne", "kuch", "kuchch", "kuchh", "kul", "kull", "kya", "kyaa",
    "kyu", "kyuki", "kyun", "kyunki", "lagta", "lagt", "lagti", "le", "lekar", "lekin",
    "lest", "li", "liya", "liy", "lo", "log", "logon", "lol", "ltd", "lunga", "maan",
    "maana", "maan", "maani", "maano", "magar", "mai", "main", "main", "mainli", "mana",
    "mane", "mani", "mano", "mani", "mat", "mein", "mera", "mere", "mere", "meri",
    "mil", "mjhe", "moreov", "mostli", "much", "mujh", "mustnt","n","na", "naa", "naah",
    "nahi", "nahin", "nai", "nd", "ne", "nearli", "neech", "neednt", "nhi", "non",
    "noon", "noth", "p","par", "pata", "pe", "pehla", "pehl", "pehli", "peopl", "per",
    "phla", "phle", "phli", "plu","plz", "poora", "poori", "pura", "puri", "que","r","raha",
    "rahaa", "rahe", "rahi", "rakh", "rakha", "rakh", "rakhen", "rakhi", "rakho", "realli",
    "reht", "rha", "rhaa", "rhe", "rhi", "ri", "sa", "saara", "saar", "saath", "sab",
    "sabhi", "sabs", "sahi", "sakta", "saktaa", "sakt", "sakti", "sang", "sara", "sath",
    "secondli", "selv", "shant", "si", "sinc", "soch", "sub", "sup", "sure", "tab",
    "tabh", "tak", "tarah", "teeno", "teesra", "teesr", "teesri", "tend", "tera", "tere",
    "teri","theek", "thi", "tho", "thoda", "thodi", "thru", "thu", "tjhe", "toh", "tri",
    "tri", "truli", "tri", "tu", "tujh", "tum", "tumhara", "tumhar", "tumhari", "tune",
     "u","um", "umm", "un", "unh", "unhi", "unho", "unhon", "unka", "unkaa", "unk", "unki",
    "unko", "unn", "uns", "upar", "us", "usi", "use", "uska", "usk", "usn", "uss",
    "uss", "ussi", "vaala", "vaal", "vaali", "vahaan", "vahan", "vahi", "vahin", "vaisa",
    "vais", "vaisi", "vala", "vale", "vali", "via", "viz", "vo", "waala", "waal", "waali",
    "wagaira", "wagairah", "wagerah", "waha", "wahaan", "wahan", "wahi", "wahin", "waisa",
    "wais", "waisi", "wala", "wale", "wali", "wo", "woh", "wohi", "ya", "yadi", "yah",
    "yaha", "yahaan", "yahan", "yahi", "yahin", "ye", "yeah", "yeh", "yehi", "ye", "yup",
]

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('words')

stem=SnowballStemmer('english')
wordnet_lemmatizer = WordNetLemmatizer()
tokenizer = RegexpTokenizer(r'[a-zA-Z0-9\']+')
stops=set(stopwords.words('english'))
hindi_stops=set(custom_hindi_stops)

def preprocess(text):
  wordlist=[]

  for word in tokenizer.tokenize(text.lower()):
      if word not in stops and word not in custom_hindi_stops:
        stemmed_word = stem.stem(word)
        wordlist.append(stemmed_word)
  return wordlist

new_df['commentText']=new_df['commentText'].apply(preprocess)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\svygralingam\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\svygralingam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\svygralingam\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\svygralingam\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\svygralingam\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
new_df.shape
# Out:
# (9800, 2)

# %%
new_df.iloc[550:600]
# Out:
#                                            commentText  Labels
# 550                                           [superb]       3
# 551                                               [ok]       6
# 552                    [mam, tamatu, nibbu, yuz, krte]       6
# 553                                             [good]       3
# 554  [hi, sour, curd, food, curd, normal, sweet, cu...       7
# 555                                            [yummi]       2
# 556  [madam, mujh, aapki, biryani, bnane, trick, ac...       6
# 557  [tri, process, today, delici, bt, rice, becom,...       7
# 558                   [thing, make, recip, look, easi]       4
# 559           [ma'am, ora, water, pleas, repli, ma'am]       7
# 560  [wife, follow, recip, last, night, came, good,...       6
# 561  [kavita, madam, main, exact, jais, dikhay, lik...       7
# 562                                            [yummi]       2
# 563           [mention, ingredi, descript, box, pleas]       6
# 564  [today, mom, gave, tri, went, unsuccess, rice,...       6
# 565  [tri, last, month, yummi, chicken, got, burnt,...       7
# 566  [excel, present, clean, cook, keep, post, good...       4
# 567                       [delici, kabita, thank, soo]       5
# 568  [hi, kabita, today, made, chicken, briyani, ur...       5
# 569  [time, enough, make, chicken, tender, al, dent...       7
# 570                                  [marin, oil, add]       7
# 571         [madam, chicken, mix, karn, tariqa, wrong]       6
# 572  [hello, kabita, watch, video, video, realli, a...       4
# 573                                [superb, fan, cook]       4
# 574                            [ghee, badl, oil, sakt]       7
# 575  [nice, chicken, biryani, thank, video, bhejn, ...       5
# 576                                [love, cook, style]       4
# 577                [good, biryani, made, today, style]       2
# 578                                        [gem, love]       4
# 579                      [mem, ism, kesar, use, zruri]       7
# 580  [kabita, mam, follow, regular, ur, dish, nvr, ...       4
# 581                                [thank, share, mam]       1
# 582  [pz, mam, rice, boil, krni, time, batin, 70, p...       7
# 583                                   [hungri, kabita]       6
# 584  [make, everi, dish, simpl, make, fall, love, c...       4
# 585  [amaz, ma'am, sure, tri, tawa, cook, without, ...       7
# 586       [1, kg, biryani, banay, time, chang, rahega]       7
# 587                    [add, instead, biryani, masala]       7
# 588  [owowwo, nice, one, mam, madam, 8, parson, chi...       5
# 589  [thank, recip, wonder, want, add, potato, step...       7
# 590                                           [awesom]       3
# 591  [mam, bataiy, biryani, essenc, rose, water, ke...       7
# 592                     [wow, mam, nice, video, thank]       5
# 593                       [mam, freez, rakhna, jaruri]       7
# 594           [basmati, rice, use, rose, water, brand]       7
# 595  [definit, gonna, tri, one, last, time, cook, s...       6
# 596  [7, 10, oil, nehi, lagana, chahiy, masala, jal...       7
# 597     [aapn, kons, brand, basmati, rice, hai, ma'am]       7
# 598                   [kabita, ma'am, sch, amaz, cook]       4
# 599  [mam, 2, chicken, ho, kaisay, bansakhtay, hai,...       7

# %%
X=new_df['commentText']
y=new_df['Labels']

# %%
X = [' '.join(document) for document in X]
X
# Out:
# ['pudina ptta dalu',
#  'chiken kacha ni rhi ga sis',
#  'hello mam love recip ingredi easili avail way explain good',
#  'awesom recip plzz make handi chicken handi',
#  'measur hai kitn liy hai',
#  'kabita mam tri ur egg biryani everyon hous love thank delici ur recip',
#  'cooker sakt',
#  'mujh bhot ach lagi apki respi mene subscrib kardia bhot ach',
#  'mam dahi jgh kr skte',
#  'wooooooo yummmmmm love',
#  'perfect biryani recip apko follow acchi biryani',
#  'hi didi alway curious biryani made thank put detail video weekend tri serv famili realli motivati',
#  'thanx respect madam appn tel nahi dala',
#  'made tast awesom thank kabita',
#  'amaz',
#  'nice video',
#  'recip cokar sakt hepleas zarur repli kijiy ga',
#  'mam ism chawal kitn g',
#  'rice oil dale',
#  'masha allah yummi thing like video way show step one one way cook realli look beauti',
#  'thank friend post video make chicken biryani like thank love friend dubai',
#  'curd skip sakt maa bariyani masala chicken masala ensabko skip sakt maa',
#  'show make merin chicken',
#  'hi kabita briyani quantiti ho cook time rahegi',
#  'awesom kabita',
#  'chicken marinett oil ghee ni daleng jis bartan bna usk nich chipkegi pls bttaiy mujh bnani',
#  'love recip',
#  'kabita didi tell brand basmati rice use',
#  'measur rice water',
#  'sweet even get mani view comment read everyon comment respond gestur',
#  'alreadi tri egg biryani time chicken mam master',
#  'delici',
#  'mujh pasand ho mam',
#  'though unabl follow languag step step prepar clear easi simpl method prepar dum briyani definit tri',
#  'mast',
#  'boht achi apki recip kamal hai',
#  'wao nice recip',
#  'isko 6 chuki unexpress comment pah',
#  'good',
#  'made today ur biryani receip tasti nice',
#  'nice recip yummi',
#  'nice recip',
#  'well explain hit home prepar mani time everyon love superb mam keep',
#  'superb mam',
#  'nice',
#  'mam wheh mix rose water',
#  'kewda water krte ism',
#  'simplest way cook biryani tri thank video',
#  'brand shahi biryani masala chicken masala differ brand differ flavour pls advic',
#  'agr dhi pudina ho',
#  'skip mint leav',
#  'hi didi mujh puchna tha dahi dala oo kesa tha mene last time dahi dala dahi khata tha chiken gravi khata ho geya',
#  'thank',
#  'oooooh',
#  'tamatar dalna hai',
#  'tast',
#  'chicken freez nehi rakhn se prblm ho',
#  'tri ur recip dum biryani good tasti chicken got burnt littl avoid pleas give suggest',
#  'shahi chicken masala combin shahi masala milta pls repli mam',
#  'big process',
#  'tri today came delici ad kade masala ingredi 1 5 time 2kg chicken 1 kg 100 gm basmathi rice follow everi step came realli well famili love recip thank share recip',
#  'kitn khayeng',
#  'javitri hai',
#  'mene tri delici thnkuu love recip mam',
#  'nice kabita sis madurai tamil nadu',
#  'nice present',
#  'wow nice',
#  '1kg chiken dahi cahiy',
#  'rice chicken quantiti ho time rahega',
#  'mene app biryani tri bahot achi achi lagi muje jada grevi chahiy thank',
#  'maam ghe jagah batter sakt',
#  'time cook stove make beef',
#  'best chef youtub mam',
#  'mam aapn kitn chawal pani pakan liy jb banati tb chawal sahj se cook hi plzz mam se dijiy',
#  'super recip mam tri awesom thank lot super keep go',
#  'amaz recip best',
#  'mam chikn pis kacch raheng pls qustion aanswer dena pls',
#  'hai dear kerala big fan hyderabadi biriyani doubt stick pan case type vessel use dum step',
#  'thank',
#  'tri testi',
#  'cook neat clean',
#  'world best briyani move canada crave mom biryani tast exact like thank 100 100 must tryyyyi',
#  'hii maam question ask taken 600g chicken dis biryani time accord vari amount chicken time stil vl chang time pls help',
#  'bhauji mutton 1 5 kg chawal 1 kg ho time',
#  'zayaah dum dene lye himaqat',
#  'pahl sochta tha doctor se hi sadi video dekhn hai hotel manag best liy husband realli lucki wish someday wife coock',
#  'tri yummi thank kabita mam',
#  "perfect recip chicken dum biriyani simpli follow step biriyani awsum first tri thank share we'll describ video",
#  'hello kabita good day dubai cook today biryani cook delici thank',
#  'made exact knw insan awesom best ever restaur thank ms kabita',
#  'nice recip',
#  'kukar ni bna skte',
#  'hyderabadi khachi ghost biryani',
#  'hello mam tri biryani recip today turn amaz thank alot delici biryani india 1 cook channel kabita kitchen',
#  'hi mam tri mani receip upma pea nut chutney phoa dosa biryani recip turn good appreci thank clear explain ur recip god bless keep',
#  'madam rice kitn rs waal ha',
#  'oh wow simpl yet delici tri',
#  'koy tri tri ra chikan jalgaya',
#  'tri great job',
#  'hi kabita tri biriyani tasti lot water collect bottom vessel solv',
#  'madam chicken dahi daln se chicken khata hai',
#  'madam simpl chawal bna skte hai',
#  'madam chiken legn leg piec dukan pr kaat kr dete hai',
#  'madam shahi biryani masala kaisey banay phir bahar karidley',
#  'measur pretti accur simpl step step explan best wish malaysia',
#  '1kg chaval lege dahi lena hai pti',
#  'jyda hai',
#  'nice kabitaji easi inform',
#  'raam chicken walo se bach rahiyo mulaa ghosit deng sorri joke',
#  'way cook good recip fantast tri biryani saunday pleas upload recip chicken momo love kabita dii',
#  'nice awesom',
#  'atta dough crack aa pressur releas ho solut',
#  'kabita mam reason learn cook made cook hobbi bachelor roommat alway wait come offic make someth credit goe mam realli awesom',
#  'hello mam tri recip today awesom never tast biryani restaur earlier',
#  'nice',
#  'magician jus love everi recip',
#  'yummi recip nice tri tasti',
#  'achchi chicken dum biryani thanku kabita',
#  'sorri pleas cook time mani minut',
#  'mam aapki recip achha laga aapka bathan tarika bahuti achha hai mam sawal hai aapn usko seal kark hai beiyani pressur cooker banan se rahega pl mam bathayeng',
#  'go first cook ever life',
#  'delici kabita mam realli great',
#  'nice recip',
#  'apn bataya hi',
#  'low medium flame either wud low medium',
#  'delici time consum',
#  'never cook biryani look video tri look ever nice',
#  'perfect recip mam thank lot keep good work',
#  'tri today hope come gud',
#  'oil daala hi',
#  'mani peopl serv want tri tomorrow',
#  'hi achhi recip hai mujh pasand hai hmesa market hi khane jana padta tha problem door ho gyi thank mam',
#  'nice cook style',
#  'biryani awesom made home major problem face make biryani bottom get burn way said noth got burn one thing add 2tabl spoon oil marin chicken even give tast',
#  'wonder chef instructor keep good work',
#  'ad cook oil wil work',
#  'pls learn telugu',
#  'ghee dalt hai tast smell hai mujh ghee kewal roti hi aacha hai',
#  'biryani pan jgah cookar bna skte',
#  'want dum biriyani want normal one seal edg pan answer pleas',
#  'tq sister amaz tri superb sister',
#  'make 2kg chicken biryani time',
#  'hi thank',
#  'super recip amaz',
#  'hello mam plzz want recip biryani masala powder plzzz',
#  'thank',
#  'nice recip',
#  '2 good mam nice recip',
#  'today tri recip awesom husband love thank alot make day',
#  'time explain kijiy plzzzzz',
#  'biryani time samjha',
#  "ma'am kitina jayada biriyani ho time rahega repli maam",
#  'tawa hai direct heat sakt hai',
#  'hii mam biryani bna bt chckn hlka lg q',
#  'bahot best',
#  'thanx mam ur biryani superb famili love',
#  'pudina patta ho kadi ptta kr sakt',
#  'man dahi replac kark daal sakt',
#  'awesom recip thank',
#  'love content keep good work',
#  'hi mam 25 peopl liy amount rice chicken chahiy plzzzzz repli mam',
#  '3 rd tym aapki recip follow hnu restaur biriyani se v bahat bahat bahat juzz lv well done mam',
#  'see peopl posit comment definit make want tri recip give go weekend thank share recip',
#  'mam nest chef',
#  'kesar ho madam',
#  "ma'am pleas app fri chicken biriyani recip video baaniy",
#  'pleas never forget write ingredi descript',
#  'explain well even cook hous make biryani well soooo yumm yumm one best biryani ever tast thank good recip biryani home',
#  'itn der biryani banan se bahar se hi order',
#  'kitchen king sabji poudar masala bataiy',
#  'nice biryani',
#  'maam one nicest youtub countri keep good work go',
#  'chicken masala lagakar fridg samai sakht hai',
#  'thora masal dar chay kre',
#  'great mam cute',
#  'india live germani ur recip life saver thankyu',
#  'marin chicken cook put rice',
#  'hi kavita tire ur recip delici one problem rice dri pleas suggest make rice soft thank',
#  'mam mujh khana lamba prose chhota aasan btaiy plzz',
#  'skip curd mam',
#  'brand basmati recommend recip recommend parboil basmati sela seila regular basmati',
#  'pudina skip skte qki local market avail',
#  '25000 calori one go',
#  'mam aloo bokhar daln ho chicken daal dene marin kart howe chicken pehl cook nei sakt ese darr chicken pakk yaa jal jae pleas repli',
#  'mam chiken ach saaf krlijiy gnda jb chiken gnda biryani test kais ho akta ag recipi chiken ach saaf kriyega safai pr dhiyan',
#  'tri recip today chicken cook beauti well rice masala got burn stuck bottom due littl steam pass dum dough two leakag spot',
#  'nice recip tri',
#  'hi kabita tri biryani home tast good use flour seal pot seal got leak middl biryani got burn bottom idea proper seal pot',
#  'hi dear made biryani yesterday instruct lower chicken got burn ruin whole dish',
#  '5 kg chicken biryani time requir cook chicken say pleas',
#  'thick pot jagah sakt',
#  'meat look uncook',
#  'make shahi biryani masala',
#  'kabita apki recip simpl hai jesh kart hai bhot hai',
#  'mam oil dalna hai',
#  'take time',
#  'tri thank',
#  'superb mam',
#  'spiciy',
#  'also tri recip multipl time realli yummi recip anyon beginn check cooker biryani recip easi quick delici',
#  'chicken pak jaayega ais',
#  'maam kia chicken layr laga skate hai',
#  'iss achchi mumma bnati',
#  'master chef ho',
#  'oh wow',
#  'kachi dum biriyani',
#  'tri realli soo yummi mam thank lot upload delici receip',
#  'galti sy 20 mint low ker dia kia keron',
#  'chicken',
#  'love',
#  'superb',
#  'nice',
#  'hello mam super',
#  'maam apn hai kitn lg liy hai tamatar hai',
#  'kabitaji main aapki recip last year mast bacchonko yaad hai savan mahina chalu se pahal banani hai isliy vapa aapki haidrabadi biryani video hoon thank kabitaji aapka recip bataneka tarika acchha hai aasan ho hai',
#  'mam apn oil nehi dala chicken marin',
#  'today first time prepar biryani turn realli well thank',
#  'like recip recip use',
#  'steam nikla hi nehi end cbi jaanch chahiy',
#  'pehl khood sikho phir sikha',
#  'love recip chicken dam biryani kabita mam realli awesom mashaa allah deffin tri recip whenev made biryani home everi time got confus rice quantiti biryani look like lott masala insiden less rice pleas give tip correct rice quantiti',
#  'love way explain nice fast tri excel',
#  'mam chicken rubber cook hai se make soft chicken',
#  'tri rspi realli nice cook biryani thnqq keep share ur rspi',
#  'shahi biryani masala ho kru',
#  'yummi mam ham tomato dal sakt',
#  'yummi',
#  'thank share cant wait make',
#  'rice kitn time ubal',
#  'easi tasti recip thank',
#  'refriger naho',
#  'thank share recipi',
#  'superbbb',
#  'mam ays pakan se chiken acchi tarha pak jayga',
#  'curd mix karn chicken jyda khatta ho gya',
#  'franc video help thank love food',
#  'love darl',
#  'nice tast',
#  'mam jb v bant jal tip doo taki jale',
#  'wonder',
#  'hey dear kabita thank make soooooo easi tast like tandoor biryani big fan love lot',
#  'super sister',
#  "today make recip yummi thank ma'am",
#  'chiz bhut hi simpl bna deti ho mam',
#  'superb',
#  'kabita mene apki recip se biryani bnai hi tasti bni thank nicerecip',
#  'biryani ban jane turant dhakkan hatana zaroori hai 1 ghant hatayeng tast fark padega',
#  'cooker',
#  'good',
#  'ham pardesh walon liy qeemti hai thank maim',
#  'thank',
#  'nice briyani kabita',
#  'wow nice',
#  'wow best home made biryani ever thank lot kabita didi',
#  'mam ghee jgha refin oil kr skte hai',
#  "ma'am tri yesterday bhot delici dahi phat gya main aapki recip step step follow phir galti ho hai",
#  'recip tast kais kareng',
#  'time cook 2kg biryani',
#  'could cook meat first layer rice',
#  'sister aapka video dekhn mene life first time biryani biryani ban gharwal ungliya chatat reh gay thank sister',
#  'agr chicken 500 gram rice 500 gram masalo sbhi ingredi measur hi rkh skte',
#  "ma'am rice chicken quantiti dikhay uss doubl ho biriyani cook time doubl yaa phir time apn bataya utn mee hi ho an mee ma'am jaldi mujh suggest jarurat hai",
#  'nice recip mam maja agya',
#  'pyaz barik kate nice recip',
#  "hello kabita ma'am main aapn bataya huy tarik se biryani acchi thank share recep",
#  'tast superb satisfi',
#  'awwsom recip',
#  'hiee how uh hope fine bdw told uh yesterday made biriyani truli work wonder lucki charm thank god bless luv load',
#  'wahh mam apka jabab hi achh se chij batati',
#  'best',
#  'never tri biriyani except made tri know turn well coz lucki charm alway ur dish help grow luv uu bless',
#  'recip best',
#  'best',
#  'get ghee',
#  'maam 10 liy bnane se cook time rahega tym lagega',
#  'soak rice',
#  'stick cookwar still prep wud remain',
#  'mam ghee jgh refin oil kr skte',
#  'mam mujh doubt hai chicken sach pak qki usual chicken bnane time hai chicken',
#  'wow nice chicken biriyani recip mam tasti',
#  'instead ghee oil',
#  'mam ghee jagah tel kr sakt',
#  'like bcoz ur cook process clear finis first time cook video subscib ur site keep best luck',
#  'hello kabita made biryani came realli well thank share recip',
#  'hi mam tri make biryani bit dri may know would went wrong also masala becam less tell solut thing thank mam',
#  'kesar dalna jaruri jgh pr jldi ni kr skte',
#  'hi mam mene chicken dum biryani bhut pasand yummi yummi thank sooooo',
#  'nice',
#  'mam mani piec come 600 gram chicken cut cut big piec',
#  'woow',
#  'dahi mandatori',
#  'nice recip question total time taken readi biryani',
#  'tasti dear mam',
#  'ur voic resembl like air hostess explain plane',
#  'reali tasti tri thank show show fri chicken kabab',
#  'kabita mam chang add cashew nut almond past almost tblspn what opinion',
#  'yr video help lot kitchen thanx give love video',
#  'humko fri chiken biriyani batayiy',
#  'kabita suppppper',
#  'mam import question mam apn esmai water dala lagabhag 40 mint cook nich chiken hai jaal baki chiz se paak v payega hamn ese pack v ho hai blast jay kyounki v apn samn chiken matan biryani pakt hai usmai gravi hai apn dala v gravi water eska trick hai mam give detail',
#  'also make like',
#  'easi delici learn frm',
#  'nice',
#  'mam pleas upload haleem recip',
#  'hello sister ingredi use 600gm chicken make instanc 1200g chicken doubl ingredi base amount meat amount ingredi remain',
#  'hello sorri watch video earlier love recip wonder cook hand contain magic tell',
#  'mam hie nivedita se brand basmati chawal biryani chawal achh nae india gate basmati karti',
#  'good recip tri',
#  'didi app reshma math jt reshma bolna',
#  'didi app aisach new rcpys post app vdo hmara frds jarur share karagay',
#  'tqqq didi muja repli daynay khaliea',
#  'kabitha didi doubt appko katnay recip cook karsakthi',
#  'kabitha mam appki lookg cuteeeeee',
#  'chicken nicha oli one layer dalna g',
#  'wow',
#  'delici recip cook cooker',
#  'need go latin indian korean groceri store collect ingredi still guarante find everyth',
#  'tri recepi soo delici thanku soo',
#  'amaz mam',
#  'good',
#  'smell kaisi khatamkaron',
#  'kesar dalni sy smell q ati hai',
#  'pakan time lagega',
#  'love cook style know aapki cook wais hi mugh pasand hai',
#  'tri awesom tasti love',
#  'mam aupka languag hai',
#  'hi yoghurt instead curd',
#  'testi',
#  'tri biryani home see video super tasti',
#  'didi kayea may kesor pani vigo saktay answar q may aj app e recip bannung plzzzzzz answar',
#  'mam dum biriyani banan pr usm halka meetha flavour tha yesa mam pleas repli',
#  'learnt cook video',
#  'mama adh kilo chicken pais upper se time waapi chahiy',
#  'bekar biryani ni pyaj jal gya adh chawal colour ni',
#  'nice recip',
#  'cute voic killer',
#  'tri yesterday tasti thank',
#  'mam 2 kg chiken biriyani banana chahti time',
#  'food colour dene se vi',
#  'long video cut describ whole step nice watch video anyon fall love mam thank glad subscrib',
#  'apko chicken acch se saf chaiy',
#  "2 watch ur chicken biryani recip i'll realli miss hostel i'll sure tri go home",
#  'knw unhealthi ur biriyani becom add food colour store bought chicken biriyani masala drain ur rice plastic contain seen ur video alway stick most everyon still extrem danger',
#  'khaak coma chalijaa',
#  '1 kg chckn rice need maam',
#  'tri follow ur step came delici thank recip mam',
#  "hi ma'am karnataka bhut hi easi recip hai bt hai chicken se pak chicken level pakaya marin hai last aapn low flame chicken se pakega",
#  'main tri bhut hi laziz easi lagi thankyou mam',
#  "thank beauti recipe ma'am maida instead wheat flour wrape around handi",
#  'didi boil rice ghee dalt',
#  'cooker sakt',
#  'time consum recip job wala cant give time prepar',
#  'mam mettha attar apn',
#  'miytha khatta dahi tha mam',
#  'nice',
#  'thank maam',
#  'aapn chicken kaccha rkha',
#  'instead biryani masala skip',
#  'tooo gud everyon like thank kabita wonder recip',
#  'today prepar let see tast',
#  'chawal daleng',
#  '2 food colour dal sakt hai kaser bdle',
#  'oil dalu',
#  'oil kauna daleng',
#  'kyon makhan shi rhega',
#  'ghee bdle makhan dal sakt',
#  'mam tri batay gay tarik se masala jal pate chipak q man bataiy',
#  'wow',
#  'woooooow',
#  'wao',
#  'masla jal gya kru',
#  'mam apn pan mei bnai hair pls tell name utensil',
#  'mam chicken curri msala instead chicken msala',
#  'kabita bataiy chicken biriyani banan keliy aluminum pot kareng total minut gas uper bithayeng',
#  'kevda essenc',
#  'dont like',
#  'prawn biriyani recip',
#  'nice',
#  'sooooper',
#  'nice',
#  'hi kabita look yummi suppos big crockpot make good advic thank share knowledg appreci video',
#  'show make biryani masala',
#  'biryani look good think put garam masala chicken',
#  'thank mam',
#  'mem apki smile',
#  'biriyani khanek liy adha kilo ata fekana padega isiliy hamko pasand nehi',
#  'ad boneless chicken make differ tast cook method',
#  'apn alu dala chicken sirf marin usa dum mea dal apn chicken marin fri pleas bhut confus hai next video mea achha se explain karya ga koy suggest dena hai repli mea digia ga',
#  'jal tha',
#  '2 kg chiken liy kitta rice curd kitta gram lgega',
#  'kabita mam tri home tast super love delici recip ankita best chef ever',
#  'easi biryani recip',
#  'hungri nice biryani',
#  'mam aapki sari recip mst',
#  "hi kabita ma'am cook cooker",
#  "ma'am dont pot make layer cook dt pressur cooker suggest utensil thn dis pot",
#  'chicken biryani thank mam',
#  'tasti biryani',
#  'jharkhand',
#  'nyc',
#  'tri menu 15 piec time cook',
#  'put recip seeg biryani',
#  'make shahi biryani masala',
#  'kabitaji 1kg biryani ingredi batayiy pleas',
#  'thank share video',
#  'ok mast welcom',
#  'waw nice thank yammi realli',
#  'mam dough wast ho jaega',
#  'cow ghee gagan vanaspati ghee',
#  'bohat acchi biryani lag hai hi banaungi',
#  'nice mam',
#  'yellow food colour',
#  'get shahi biriyani masala also chicken masala pleas let know',
#  'nice video mam',
#  'super',
#  'best',
#  'tste',
#  'mam biryani masaledar keliy chahiy',
#  'like recip',
#  'chicken gal hi esa ku',
#  'nice mam main bhut testi thank',
#  'nice',
#  'yummi',
#  'tasti thank kabita',
#  'yummi',
#  'mam agr itta tym tk chikn chlaau pan chipkega',
#  'thank sekhani allah mngheban',
#  'bhaut easi se mam ni bataya',
#  'hi mam good morn mujh chicken biryani banana hai 12 peopl pls give proport rice curd chicken 2 day made chicken biryani awesom tast love today make biryani guest pls repli',
#  'recip banati ho',
#  'madam briyani rice shahi jira hai',
#  'hyderabadi biriyani jawab nehi samna nehi',
#  'like cook time heat precaut best',
#  'record video phone camer',
#  'hello kabita tri chiken biryane',
#  'super',
#  'mam ate doug se isko dhakan charo taraf lagaya achhes set lia ham pressur cooker nehi sakt stick pan badal normal pan kareng chiken nich lagega nehi an mam',
#  'mam bina kesar ni bn skta ghee jagah oil ho skta',
#  'thank',
#  'supop',
#  'love ur grt cook big fan ur',
#  'chiken kacha e dal dey gye smell gi chiken mujhi pasnd ayi',
#  'kabita chicken uncook hi reh chicken fri place',
#  'mam cup 250 gram basmati rice mani piec come 600 gram chicken mention cut chicken piec larg piec mean mani piec come 600 gram cut larg piec',
#  'khatta dahi add meetha dahi',
#  'ossam mam',
#  'briyani got popular inlaw credit goe dear thanku share kepp rock like oli',
#  'ism flavour hai colour',
#  'tri yummm mam 10 person liy chaawl chicken dahi piyaz lage ga time cook pade ga',
#  'maem ky hm pan jaga cooker bna skte',
#  'pleas tell artifici color food recip',
#  'hello recip hm tri krte tasti banti thank',
#  'jawab',
#  'mumma tri tha',
#  'best recip mam',
#  'behan pyaz fri pehl seek biryani mazak maro',
#  'apn rose water screw pine dala',
#  'colour dalna complsari hai',
#  'mam aalu dalna kais daleng',
#  "kabita mam i'v make chicken biryani follow recip alway came wonder question proport curd almost 650gm 1 kg chicken appear lot could suggest curd rice consid 1 kg chicken",
#  'video got 11m view red colour rice',
#  'naaam bada darshan chota satisfi recip lot mistak',
#  'nice video',
#  'tri make bt bottom layer get burn tip avoid pleas help',
#  'pleas advis cook pressur cooker lid cover instead pan air lock dough heat time cook pressur cooker',
#  'mam aapki dish hameesha heh aachchi rehti hai',
#  'badiya nice',
#  'biggest fan cook kabita sister',
#  'kabi mayri post answer day dia dear sister',
#  'kabita wan tri recip chicken masala readi made shayad particular name ho haray recip hy dain masala waitinf',
#  'rice use',
#  'tri hubbi love thank kabita',
#  'nice',
#  'quantiti ho dam tymng rhega',
#  'nice',
#  "wow tri delici thank ma'am",
#  'kikar biryani',
#  'tarik mujh masala chiken pak',
#  'thank realli help',
#  'rrt44',
#  'mam plzz make chicken chilli',
#  'kabita mam nail shukriya ais hi receipi upload kart rahiy',
#  'pressur cooker cook rice',
#  'tasti',
#  'cooker instead pan',
#  'keser kart lakin logo amir mehengi sij kharid sake logo paisa milta hame milega gurajih simpl tarik se khna bani usm atcha age se mehengi sij batay kyonki lob amir',
#  'tri chicken burn tri 1s',
#  'mam mene biryani nich se jal gai',
#  'shahi biryani masala',
#  'kitn mare biryani kha hehe',
#  'mam presur cooker',
#  'wish wife',
#  'sister food color z nt gd fa hlth',
#  'deserv 10m subscrib mam',
#  'realli like recip bcz simpl easi quick tasti inde mace powder instead whole mace',
#  'nice',
#  'superb superb chicken biyrin',
#  'kiti chaan banvali biryani',
#  'wow',
#  'awesom easi prepar',
#  'jada pyaj daln se problem',
#  'ag kesar dale',
#  'one best outcom wht ive made watch video jus follow wht say done love kabita thank recip',
#  'tri cook tomorrow',
#  'nich oil nay daala chicken nich jalega nay chicken',
#  'wow',
#  'eat',
#  'show cook record shoot time perfect',
#  'way cook hyderabad',
#  'voic good',
#  'ook',
#  'vari nice',
#  'nice recip',
#  'mam layer kartr waqt bina ghee laga se nich lag chicken piec ham layer chicken nek layer rice fie layer chicken layer rice ais sakt',
#  'big fan keep post recip lot love',
#  'thank biryani liy',
#  'keep overnight freez fir marin',
#  'infreez',
#  'good recip',
#  'make without curd shahi biryani masala',
#  'husband say jadu agaya tumhr hatho bcoz ur receip thank mam lot love',
#  'nice mam tri thanku acchi easi resip share',
#  "ma'am baat bataiy main suna hai vej se dudh dahi ghi dur hai khane 12 se 24 ghant hi dudh dahi ghi khana chahiy warna charm rog hai daal bat sachchai hai ma'am",
#  'mam saffron import',
#  'mam pleas app colour kia hae bo milta hae price hae bataei',
#  'kabita mam ur best',
#  'kabita mam subscrib bahot achchi hai mujh video dekhna mujh bahot pasant hai like kabita kichan',
#  'nice plzz telm chicken khucha mein suna tha chicken fri hai plzzz confus dorr karoo',
#  'recip achi hi',
#  'mam ur fan',
#  'love ur biryani made twice everyon love thank ur wonder recip',
#  'mam oil base oil rep mam',
#  '1000 time yummi get',
#  'layer step want ue microven dum mujha cz gas layer mujha dare lagthi jal help microwav dum kais',
#  'descript box lekhna lekha nah',
#  'tnx tasti chicken pak tnx love',
#  'c result baba pls birayani ban jay thik thik',
#  'accord good chef',
#  'yummmmyyyyyyi',
#  'chicken pakk gayaa hai pls tell mam',
#  'modi pakoda malum hai anti jii',
#  'love chicken mam chiku v recip jarur bnay hame btay',
#  'oil kyea',
#  'pressur cooker instead cover top dough',
#  'niceeeeee',
#  'nice tri best hyderabadi biryani world famous',
#  'thank mam',
#  'easi mam l tri definit',
#  'mam biryani dahi skip sakt bacch dahi se allergi biryani bina dahi ban dahi option',
#  'hi tri way littl bit steam come ok done someth rong repli 1st time cook',
#  'superb',
#  'ok',
#  'mam tamatu nibbu yuz krte',
#  'good',
#  'hi sour curd food curd normal sweet curd sorri know noth cook want surpris wife anniversari',
#  'yummi',
#  'madam mujh aapki biryani bnane trick achhi lagi video kese download karuu',
#  'tri process today delici bt rice becom dri wonder el cud make rice dri suggest',
#  'thing make recip look easi',
#  "ma'am ora water pleas repli ma'am",
#  'wife follow recip last night came good ask make tonight',
#  'kavita madam main exact jais dikhay likh biryani jaal kiu',
#  'yummi',
#  'mention ingredi descript box pleas',
#  'today mom gave tri went unsuccess rice cook well shown video chicken peic complet burnt chicken turn coal heat biryani exact time exact flame shown video spoil plan mayb day',
#  'tri last month yummi chicken got burnt avoid',
#  'excel present clean cook keep post good luck',
#  'delici kabita thank soo',
#  'hi kabita today made chicken briyani ur video came realli outstand yummi husband love made day ur delici yummi tasti briyani love thnkuuu thnkuuu',
#  'time enough make chicken tender al dent type',
#  'marin oil add',
#  'madam chicken mix karn tariqa wrong',
#  'hello kabita watch video video realli amaz way cook realli appreci keep best luck',
#  'superb fan cook',
#  'ghee badl oil sakt',
#  'nice chicken biryani thank video bhejn liy kavita',
#  'love cook style',
#  'good biryani made today style',
#  'gem love',
#  'mem ism kesar use zruri',
#  'kabita mam follow regular ur dish nvr fail get appreciaion mother',
#  'thank share mam',
#  'pz mam rice boil krni time batin 70 persent time boil mra rice kbi ziyada kbi soft pz batin 70 rice time boil',
#  'hungri kabita',
#  'make everi dish simpl make fall love cook bless',
#  "amaz ma'am sure tri tawa cook without dn longer increas flame stick pan work",
#  '1 kg biryani banay time chang rahega',
#  'add instead biryani masala',
#  'owowwo nice one mam madam 8 parson chiken biryani dum qanti ketna chiya',
#  'thank recip wonder want add potato step add',
#  'awesom',
#  'mam bataiy biryani essenc rose water kewra water marinad karth waqt 1 tsp rice banath waqt 1 tsp dal sakhti pleas mam doubt bataiy',
#  'wow mam nice video thank',
#  'mam freez rakhna jaruri',
#  'basmati rice use rose water brand',
#  'definit gonna tri one last time cook slight differ recip ad kewra rose water someth went wrong smell overpow aroma biryani mayb misjudg quantiti rose water ad kewra water made tast like agarbatti use rose kewra water essenc',
#  '7 10 oil nehi lagana chahiy masala jal nehi',
#  "aapn kons brand basmati rice hai ma'am",
#  "kabita ma'am sch amaz cook",
#  'mam 2 chicken ho kaisay bansakhtay hai zaida ho matlab 13 ppl kay liy',
#  'pak chuki madam chicken piec',
#  'hey kabita brnd pan vessel krtihe',
#  'biryani pressur cooker sakt hai',
#  'chicken cook well pretti sour tast due curd tast like shit',
#  'nice',
#  'kabita apki recip dekhn pehl like kr diy apki sari recip achhi',
#  'nice prepar tri nirmal',
#  'kabita mam went recip chicken dum briyani earlier ad briyani essenc kewra water rose water briyani add put add marinad cook rice',
#  'hii kabita didi mein aapki recip tri hai sundar dikh hai todo ter readi ho jayegi fir tast kark aapko repli deti happi makar sankranti',
#  'skip black cardamom chang tastr',
#  'yammmi',
#  'blood lga tha dhekhn hme chicken bireyani se nafarat ho gai',
#  'mam apn chiken dhoya ni',
#  'thanku',
#  "wowwwww super mam i'll tri tomorrow",
#  'bhabhi liy plet parsal kardo pleas',
#  'mam last rice kasar kani reh jay mean 5 10 kach reh jayein wat wud solut',
#  'nice',
#  'aapki voic bohut achhi hai',
#  'mam nonstick pan ho chicken jalega',
#  'apn madam',
#  'cute',
#  'nice kabita',
#  'zam zam biryani dikhay',
#  'ais banti biryani',
#  'chicken biryani recip',
#  'mam chicken corma recip baty',
#  'nice',
#  'yummmmyy',
#  'mine biryani 1',
#  'tip realli good',
#  "ma'am link recip pleas",
#  'mem 1kg biryani banay dalna padega chiz',
#  'mam biryani essenc rose water kewra water 1 tsp marin karth waqt rice baneth waqt 1 tsp dal sakhti dhakad phool marinad karth waqt rice baneth sakhti sakhti kina dhaakad phool mam pleas repli',
#  'mam alway see ur recip realli like ur recip',
#  'didi nich jal gya tri jal gya',
#  'mam ur chicken biryani outstandig like ur recipi',
#  'dislik comment',
#  'didi mujh biryani dukan kholni chicken jal aachi seal karn tareeka batayein jiss bhaap bahar nikl pleas bhut zaroori',
#  '600 gram chiken se jada shaktya key',
#  'thank mam',
#  'welcom mam',
#  'pressur cooker ho skta',
#  'hii mam biryani aluminim jarmal bhagon sakt hai repli',
#  'nich se chipkega',
#  'tri recip everyon like thank kabita',
#  'hello mam recip bhut bdhiya hai',
#  'mam question hei chicken cook korna hei',
#  'infreez cant wr keep room temp',
#  'thank video biryani amaz expect tast guy plzzz watch video prepar',
#  'gaavran chicken sakt',
#  'cook rice two time think need cook rice cook chicken cook yet know could somebodi tell like mayb basmati rice strong differ smell anyway love pakistani food',
#  'thank video',
#  'omg best recip mom cook togeth follow recip turn good finger like good make share channel friend famili thank recip pleas upload video like',
#  'kavita mam apn direct chicken marin biriyani ism chicken achha se boil chawal jal ni',
#  'thanku mam apk ai recip help hai thanku',
#  'aami ektu oil kort pari',
#  'ei biriyani tee kono oil nei',
#  'ami ajk banacch ei ta',
#  'good',
#  'superb kabita',
#  'wow',
#  'wow mom home tri biryani',
#  'add black chilli',
#  'mam mu karithili je pita lagila',
#  'aluminium foil instead flour',
#  'aaataa lagaan badl agr biriyan coocker dam rakh hai',
#  'like cook',
#  'pleas mam bataiy',
#  'mam ism curd milana jruri hai',
#  'yammi',
#  'chicken pakayng kacchha lgega',
#  'mam 1tsp tandoori chicken masala dal sakhti tast',
#  'christma pakka sister make biryani',
#  '',
#  'nice video',
#  'kabita neat perfect recip love hope get recip main chicken mutton egg fish',
#  'kabita mem tank aj tri',
#  'mam chicken nich lag jaati trick jiss nech lage',
#  'like style',
#  'thankyou mam prepar dish wife',
#  'thank aunti',
#  'nice recip',
#  'zaiqa e yasmin also good',
#  'ism rose water dal sakt',
#  'nice',
#  'kavita main tri famili guest paasand ayi main recip kay share kee',
#  'nice thank',
#  'good',
#  'wast ho jaega',
#  'nice biryani mam',
#  'mam shahi biryani masala jagah chicken biryani masala kr',
#  "mujh 3 question puchna ha 1 litr pot biryani ha 2 pot cover karn liy glass lid ha biryani dum dene liy glass lid se cover 3 biryani pudina karn se mean karn se tast kharab kind repli ma'am",
#  'biriyani jal jayaga kaya',
#  'superb',
#  'fridg mean defridg',
#  'pas pudinapatta nehi hein dal bataiye morn banungi',
#  'thank give nice idea make biryani',
#  'nice way make dum biryani',
#  'awesom made dish today turn tasit thank lot',
#  'kabita mam black jeera 1 tsp marinad kart waqt rice banat waqt 1 tsp sakhti',
#  'thank advis liy age tri',
#  'good',
#  'kesar eag kesar kr skte',
#  'tank',
#  'confus',
#  'mam rice quatiti cup tell kari kitnay cup rice leay apnay cup size',
#  'sorri kavita bura maniy experi share pareshan ho bhuk se khayi dantn laga apn',
#  'ni kesi biryani time lag biryani jal nich se sari sari ism photo option ni warna apko daal deta chicken hi ni jal',
#  'wow',
#  'steam nikla',
#  'superrr mam',
#  'hello aunti pleas adopt',
#  'look tasti make today',
#  'mam 6 green chilli past sakhti',
#  'nice one',
#  'mam thand mosam bina freez rakh v marin ho skta',
#  'like ur reciepi gud job',
#  'nice',
#  'kabita ur small littl fan',
#  'superb',
#  'behan piyaj hao',
#  'super mam',
#  'steel pan yes stop chicken get burnt',
#  'tha habbi huya tha',
#  'mam mene color',
#  'nice',
#  'hungri',
#  'hello recip follow ker ti briyani briyani chicken jal gya nich se 3 time asa time batya hai hi tha',
#  'piyari hai awr meetha',
#  'mam time ey jalega nahi nich se',
#  'good',
#  'v v v v good',
#  'nice thank',
#  'love yar',
#  'didnt know put ghee moistur rice',
#  'hydrabadi bryani lemon juic daltey hai briyani dum denay pahlay humloag',
#  'pls write ingredi',
#  'pagal ho bnati ho jb chiken kacha hai rice 50 pakka huwa hai jb usko payeng tb chawal gal jayenga samjhi bahan',
#  'kavita mam ham khade masalo grinder mix kark daal sakt hai',
#  'marin chicken overnight soft tast would odd',
#  'tri',
#  'mujh tha v apk video se bahot ach se pai nice',
#  'food colour naaa',
#  'majedar biryani definit go make love thank mam',
#  'nice recip like',
#  'yummi tri',
#  'mam 4 hour liy chicken marinad sakthi',
#  'hello mam humn pehel bar ehi recip realli mam awsm yummi',
#  'maa tel kharab gst mehga ho hai',
#  'gajab',
#  'favorit perfect',
#  'cook use pressur cooker without whistl chicken cook',
#  'wow kabita mam tasti',
#  'leav note appreci biryani recip big hit home stop order biryani look forward recip',
#  "hello kabita ma'am best job recip perfect good keep go best luck",
#  'nice',
#  'der paka oil pani vi dya chicken rice nich masala chicken jal pleas repli',
#  'mam biryani apn kitn logo keliy',
#  'made biryani yesterday turn like ur actual masala chicken lot cos like gravi less dahi rice pls tell',
#  'wow',
#  'mei hostel rhta fridg ni jruri chiken marin usko fridg rkhna jruri let know',
#  'perfect',
#  'hiii mam biryani niches jal mean',
#  'tri tonight websit link forgotten add salt chicken marin guess rectifi',
#  'mashaallah bhot umda',
#  'kabila great recip thank',
#  'hello kabita mam prepar shahi biryani masala powder get outsid',
#  'thaq kabitha',
#  'salaam kabeta apko subscrib kyia thank',
#  'hi zda tast bryni bi dikhay hi hsbnd zda psnd ayi khush huw hsbnd thnk',
#  'kabita mam chicken masala garam masala shahi biryani masala jeera powder coriand powder nutmeg powder black pepper powder add sakth mujh best hyderabadi style chicken dum biryani flavour chahiy pleas mam repli',
#  'biryani hamesa nich se jaljata hai repli',
#  'chiken dahi daln se hai aunti',
#  'nice voic',
#  'best mam 10 million view still count keep mam',
#  'chan',
#  'want tri dis',
#  'ghee deshi',
#  'hi kabita nice recip pleas tell brand kadai use fri onion like design',
#  'kabita mam import keep tava keep stove top low flame repli',
#  'mam zruri ni hy shahi biryani masala dalna ho',
#  '1st time abl make yummi chicken dum biryani earlier made sever unsuccess attempt thank',
#  'nice',
#  'thanxx mam mei tri krugi',
#  'mam kesar compulsori hai',
#  'made biryani awesom everyon home like realli thank keep post',
#  'nice',
#  'nice',
#  'horribl tri bt hmko pasnd ayi chiken ws cook get cook oil dont like apki saro recip bshut acchi bt tri feel smjh banay',
#  'repli',
#  'hmm biryani look yummi',
#  'fb name ha',
#  'kavita mam rice chicken quantiti zada dum lie time dena',
#  'mujh recip achi lagi hai fb naam hai',
#  'kabita mam marinad karth waqt spoon salt add',
#  'nice',
#  'hi',
#  'tri biryani recip kabita realli appreci hard work',
#  'nice',
#  'chicken biyani bhagol sakt give an',
#  'mam hyderabadi recip lime juic dalth hyderabadi flavour lime juic dal sakthi mam bataiy pleas spoon lime juic dal sakhti kind repli import doubt kabita mam',
#  'thanku mam good ho',
#  'mam 4 spoon ghee matlab tblspns tsp',
#  'kabita mam put bay leaf marinad',
#  'marinad karth waqt chicken ginger garlicpast pudina coriand leav black elichi green elichi cinnamon clove javitri curd green chilli salt haldi chilli powder garam masala coriand powder jeera powder shahi biryani masala 1 4 tsp nutmeg powder 4 spoon ghee 1 4 onion dalthi',
#  'kabita mam spoon ghee dalu marin karth waqt kitn onion dalu marin karth waqt',
#  'chicken paak ussay rice tarha pehlay pakkanay jarurat hai',
#  'kabita mam superb recip clear video clear explain origin hyderabadi biryani recip',
#  'mam spoon nutmeg powder add pleas bataiy',
#  'nic',
#  'mam nutmeg powder dal sakth matlab apka opinion matlab coriand powder garam masala powder jeera powder lagega tast spoil apka opinion',
#  'biryani masala kais bnaat hai market kbhi mila',
#  'hi mme kind water make dough cold warm',
#  'hello mme nice briani ask someth mind put water cook stick pan without water',
#  'apn video hi detail se btaya hai',
#  'yummi',
#  'super mam',
#  'wow great recip thank video',
#  '3 kilo biryani liy masala lage ga',
#  'mam coriand powder jeera powder garam masala powder 2 tsp dalu pleas bataiy',
#  'mam matlab 2 tsp mam apka opinion kitn spoon dalu pleas bataiy',
#  'mam apn ghee 1 tblspn layer 1 tsp matlab apn aada quantiti kijiy 1 tsp dalu',
#  'mam patanjali cow ghee sakthi',
#  'mam cow ghee sakth bahar qualiti',
#  'seal karn cooker blast zimmedaar',
#  'tri right wish luck',
#  'dewsi ghee mean cow ghee',
#  'doodh kesar full night tk bhigok rkhna hai yaa instant',
#  'make shahi biryaani masala',
#  'kouc test hai wat video',
#  'ghee import',
#  'perfect receip',
#  'waaaw tasti biryani myney hey tast yummmm',
#  'sorri comment',
#  'asi chicken kachi rhygi',
#  'apni chicken pakya e ni',
#  'chicken kaccha nehi raheha',
#  'good',
#  'kounsa chawal achha rahegaa matlab long grain rice name',
#  'awesom recip',
#  'mujh help chahiy mam mujh biriyani 10 person liy banana hai pls batayeng sare ingredi measur rahega dushera guest aayeng plss bataiyeh kais achha banega',
#  'kewra water rose water add karn baadh saffron milk orang colour add sakthi pleas bataiy kabita mam kewra water colour chemic reaction',
#  'hame spoon coriand powder jeera powder garam masala powder add',
#  'normal rice sakt mam pleas bataiya hame apk recip dekhkar sabs best christma dish banana',
#  'coriand powder jeera powder garam masala add sakthi marinad karth waqt pleas bataiy kabita mam',
#  'like cook',
#  'thank god subtitl look pretti easi thank',
#  'hi mam saw recip channel name dark moon entertain thought tell',
#  'ooh ok',
#  'veg dish kro veg veg jayada tasti hai',
#  'dhania powder jeera powder marinad karn sakt biryani tast spoil',
#  'awesom biryani mam',
#  'great resipi',
#  'bakwash',
#  'nice',
#  'iam done enjoy',
#  'thank kavita share dis yummi recip made today made delici thank',
#  'nice',
#  'bt great video',
#  'mujh sirf khaan maza hai',
#  'pudina patta ho uski jagah hai humar easili market may milta hai advic',
#  "first time ever cook biryani treat mom i'v follow everyth said cook best biryani i'v ever tast thank perfect recepi instruct",
#  'competit tast briyani achi hai appki pressur cooker achi hai repli fast muje sunday banani hai',
#  'badi elichi import shop avail',
#  'kabita love biriyani thank idea',
#  'hello kavita mam tri recip follow ur step step instruct biriyani turn awesom thank wonder recip detail',
#  "woow maam need thank lot bahot asan lg tha i'll definit tri",
#  'wow tasti',
#  'reali awesom testi tha biriyani thank lot mam',
#  'osmmmm',
#  'definit tri',
#  'wow nice ur explan made easi maam need fri chicken direct put marin chicken',
#  'thank madam',
#  'nice',
#  'love cook find best chef youtub trust best chef among chef',
#  'super duper',
#  'thank',
#  'hn saari biryaani jala dikh hai nikalt time',
#  'madam plastic stainer plastic tool hot food',
#  "doubl dose saffron skip orang color also can't stand fresh coriand leav make sick tast like stink bug parsley",
#  'kabita aapki bhut bdi fan aaps milna chahti kolkata v kolkata se hi',
#  'nice',
#  'koun chawal kartehain mam',
#  'main tri tha',
#  "thxz kavita mam im frm punjan india i'll tri definet tri thxz video",
#  'hi kavita today tri ur biryani recip realli yummi thank',
#  'nice yummi',
#  'normal flame chicken kais paka madam bet chicken paka hi hogaa',
#  'ok ty mam',
#  'like dish',
#  'cook biryani sinc long see recepi tri unfortun chicken bottom layer get burnt stick step still abl come issu could pleas suggest exact may go wrong',
#  'nice recip mam tasti',
#  'compani basmati rice',
#  'thank actual show recip dum style peopl mix rice chicken fulli cook call dum biryani',
#  'tri soon',
#  'ghee se zyada moistur hogya tha oil daln se',
#  'freez chicken ni rkhe kr skte usk jgh say',
#  'ok kavita thank',
#  'samajh',
#  'khala aloo dalay hi ni',
#  'kavita saudi sari cheez se lao batayi hai',
#  'thank mam',
#  'chhota bada chamach size hous hous differ quantiti batat spoon size dikha digiy video',
#  'mujh khana hai biryani mujh banan',
#  'profi thank inform',
#  'marin chicken night keep fridg',
#  'mam biriyani hi hoto serv kiyni',
#  'quantiti want make one person',
#  'tri son ask everi sunday',
#  'made tast awsm gr8 easi recipi',
#  'color mandatori',
#  'hi kabita tri recip today turn awesom everyon famili like thank',
#  'vri nice',
#  'pleas make video zam zam pulao search tasti zam zam pulao recip mani day get suitabl recip wait zam zam pulao recip mam',
#  'hous veryyyyyyyyyyyyyyyyyyyyyyyy beauti',
#  '2 kg se hi time ho ga',
#  'agr ism potato add ho usko chicken marin krke daleng btay',
#  'last part dough cap od like liter need part',
#  'chiii mene tri ghr pr biryani naam insult plzz guy tri mt ghr pr',
#  'cook today chicken dum biryani cook fast time awesom think help wapsid',
#  'mem shahi paneer daal makhni bna sakt ho',
#  'mam ham kaleji deal sakt',
#  'also tri recip nice',
#  'birayani achhi thank kabita nice recip',
#  '',
#  'cook today',
#  'yummi rcp mam thank',
#  'tasti like',
#  'mam want tri chicken kchcha ni rhega smell ni aaegi tell',
#  'thank madam',
#  'mashaallah',
#  'coriand powder biryani requir',
#  'aapn 3rd stage layer mujh ghee oil dalna chicken daaln se pehl apn daala im confus pleas help',
#  'hey tri super se thanx ton keep shine',
#  'good video sorri say hyderabadi chicken biryani',
#  'javtre',
#  'actual doubt chicken aches pakta marin direct rice dal ho app pleas explain mam',
#  'nice real video',
#  'yu 2good mam apki recepi explain way bhot hai',
#  'nice tasti recepi',
#  'dish awsom',
#  'mene awesom realli tasti',
#  'nice',
#  'sorri sweet',
#  'good',
#  "look yakhni biryani recip can't find",
#  'like biriyani',
#  'bina pani jal',
#  'yummmmmi',
#  'ok biriyani atar mitha atar hai usko jism se bgiriyani orgin cent atehai',
#  'fridg ho kese banayeng',
#  'kukar istem kr skte hai',
#  'mam curd sour lena hai pleas reapli an mam',
#  'tooooo yummmmmmmmmyyyyyyyyyy',
#  'awesom',
#  'oil dala hi',
#  'lolllll biryani hai sabji ese todhi banti hai pagal biryani',
#  'watch middl night mcdonald option guess',
#  'kesar necessari food colour',
#  'ingredi use high compar briyani made good',
#  'mast mam tri today',
#  'nice one',
#  'v nice',
#  'main tri tasti thank alot',
#  'main tri last friday delici awsm',
#  'kabita aapn khosboo liy',
#  'kabita want tri pleas mujh batayeng chawal long fluffi kais banega high qualiti basmati rice restaur long fluffi banta ha pleas repli',
#  'thankyou kabita kitchen',
#  '1kg chicken liy quantiti masal add padega rice quantiti badani padegi',
#  'easi process mam thank',
#  'owsom',
#  'nice biryani',
#  'maza aagaya kasam se sanjita',
#  'surelli tri shraavan',
#  'mam boneless chicken ho der pakana hai jaldi gal basra hai',
#  'fridg vegetarian',
#  'hello kabita mam ghee vanaspati pure ghee pleas repli quick',
#  'love kabita aunti kitchen',
#  'muze biwi chahiy sirf khana banan ho baki samhal',
#  'mam pleas 1 kg biryani liy video',
#  'mam chahwal bhogona adha ghntta sirf ubalna',
#  'hai',
#  'help thank recip cook today yummi',
#  'nice mam thank',
#  'make khichda',
#  'nice',
#  'mam bas 1 hr marin krke fir bas dum chadha chicken pakk kachha reh gya',
#  'chicken badhey piec jalt ni proper cook ho jate',
#  'mam chicken biryani tast coriand biryani take risk recip hydrabadi',
#  'kabita dahi dalna zrori',
#  'javitri matlab',
#  'ohhhhhhhhhhhhhh nice',
#  'cook acchi hai naam batay mujh aaps biryi sikni hai',
#  'bariki se aapn batya hai mam',
#  'hi kabita today tri chicken biryani recipi your first time life cook recipi tell absolut fantast shocj wish could tast thank wonder recipi tc gd bless',
#  'osm',
#  'thank lot recip never knew first tri would success',
#  'first briyani trust awesom big thank kabita kitchen',
#  "jst cook biryani trust guy realli good jst follow process step step told u'll end super tasti lip smack biryani kabita didi ur best thank",
#  ...]

# %%
lbl=LabelEncoder()
y=lbl.fit_transform(y)

# %%
y=to_categorical(y,num_classes=7)

# %%
model_en=fasttext.load_model('./cc.en.300.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
X=np.array([model_en.get_sentence_vector(sentence) for sentence in X])
X
# Out:
# array([[-0.04865845, -0.02029513,  0.00281682, ...,  0.04467136,
#          0.0015281 , -0.00535533],
#        [ 0.00939113, -0.07598583, -0.01752039, ...,  0.07207707,
#          0.03232015, -0.03124447],
#        [ 0.02100777, -0.01061132,  0.00563888, ...,  0.06104375,
#          0.01299675, -0.00439147],
#        ...,
#        [ 0.03667046, -0.00809222, -0.023444  , ...,  0.05898034,
#          0.01075574, -0.0243484 ],
#        [ 0.01814937, -0.00052348, -0.05576143, ...,  0.06553596,
#          0.03396218, -0.02669046],
#        [ 0.02075222, -0.06449727, -0.03291111, ...,  0.09440843,
#          0.01172403, -0.03573036]], dtype=float32)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.20)

# %%
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, PReLU,LeakyReLU
from sklearn.metrics import accuracy_score
from keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization
from keras.regularizers import l1, l2

np.random.seed(42)


# Reshape input data for LSTM
X_train = X_train.reshape(-1,1,300)
X_test = X_test.reshape(-1,1,300)

model = Sequential()

model.add(LSTM(64, input_shape=(1,300)))
model.add(Dropout(0.5))
model.add(BatchNormalization())

model.add(Dense(25,activation=PReLU(),kernel_regularizer=l2(0.001)))

model.add(Dense(40,activation=LeakyReLU(),kernel_regularizer=l2(0.001)))

model.add(Dense(30,activation='relu',kernel_regularizer=l2(0.001)))

model.add(Dense(35,activation='tanh',kernel_regularizer=l2(0.001)))

model.add(Dense(7, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# Train the model on this fold
model.fit(X_train, Y_train, epochs=150, batch_size=150, validation_data=(X_test, Y_test), callbacks=[early_stopping])

# %%
accuracy = model.evaluate(X_train, Y_train)[1]
print("Accuracy on train data: {:.2f}%".format(accuracy * 100))

# %%
accuracy = model.evaluate(X_test, Y_test)[1]
print("Accuracy on test data: {:.2f}%".format(accuracy * 100))

# %%
from flask import *
import numpy as np
from keras.models import load_model
import fasttext
import re

model=load_model('model.h5')

en_model=fasttext.load_model('cc.en.300.bin')


app=Flask(__name__,template_folder='templates')

def preprocess(text):
   process_text=re.compile('[^A-Za-z0-9]')
   text=re.sub(process_text,' ',text.lower())
   return text

def vectorize_text(text):
    vector = en_model.get_sentence_vector(text)
    vector = np.reshape(vector, (1, 1, 300))
    return vector

@app.route('/')
def home():     
    return render_template('index.html')   

@app.route('/predict', methods=['GET','POST'])
def predict():
    if request.method == 'POST':
        input_text = request.form['text']

        processed_text = preprocess(input_text)

        vectorized_text = vectorize_text(processed_text)

        prediction = model.predict(vectorized_text)

        predicted_class = np.argmax(prediction)

        classes = [ 'Gratitude','About the recipe','About the video','Praising','Hybrid','Undefined','Suggestions and queries']
        result = classes[predicted_class]
    

        return render_template('index.html', prediction=result)
    
@app.route('/reply', methods=['POST', 'GET'])
def replyMessage():
    auto_reply = None 
    if request.method == 'POST':
        reply_msg = request.form['reply']

        predict_class=request.form.get('prediction')
        
        if predict_class == 'Gratitude':
            auto_reply = 'Thank you'
        elif predict_class == 'Praising':
            auto_reply = 'We appreciate your positive feedback!'
        else:
            auto_reply='Sorry! next time'
            
    return render_template('index.html', prediction=predict_class, auto_reply=auto_reply)

if __name__ == '__main__':
    app.run(debug=True,use_reloader=False)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [01/Dec/2023 21:10:54] "GET / HTTP/1.1" 200 -
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000224A0F8AF20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 29s 29s/step
# 127.0.0.1 - - [01/Dec/2023 21:11:59] "POST /predict HTTP/1.1" 200 -
